# %%
import pandas as pd
import numpy as np

# %%
flats = pd.read_csv(r"C:\Users\avanindra Bose\OneDrive\Desktop\Real State Project\Cleaned Datasets\flats_cleaned.csv")
houses = pd.read_csv(r"C:\Users\avanindra Bose\OneDrive\Desktop\Real State Project\Cleaned Datasets\house_cleaned.csv")

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.to_csv("gurgaon_properties.csv",index=False)
