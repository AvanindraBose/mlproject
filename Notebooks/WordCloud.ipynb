# %%
import pandas as pd 
import numpy as np 
import pickle 
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df = pd.read_csv(r"C:\Users\avanindra Bose\OneDrive\Desktop\Real State Project\Cleaned Datasets\gurgaon_properties_missing_value_imputation.csv")
df1 = pd.read_csv(r"C:\Users\avanindra Bose\OneDrive\Desktop\Real State Project\Cleaned Datasets\gurgaon_properties.csv")

# %%
df.head()
# Out:
#   property_type                 society      sector  price  \
# 0          flat             rof aalayas  sector 102   0.45
# 1         house  huda sector-56 gurgaon   sector 56   3.60
# 2          flat   parsvnath green ville   sector 48   2.50
# 3          flat    emaar gurgaon greens  sector 102   1.35
# 4          flat          raheja sampada   sector 92   0.65
#
#    price_per_square_feet  bedRoom  bathroom balcony  floorNum   agePossession  \
# 0                 6000.0        1         1       2       6.0  Relatively New
# 1                24845.0        5         5      3+       3.0  Moderately Old
# 2                12820.0        4         5       3       1.0  Moderately Old
# 3                 8181.0        3         3       3       5.0  Relatively New
# 4                 4744.0        3         2       3       6.0  Relatively New
#
#    built_up_area  study room  servant room  store room  pooja room  others  \
# ...

# %%
df1.head()
# Out:
#                                    property_name property_type  \
# 0               1 BHK Flat in Sector 102 Gurgaon          flat
# 1  5 Bedroom House for sale in Sector 56 Gurgaon         house
# 2                4 BHK Flat in Sector 48 Gurgaon          flat
# 3               3 BHK Flat in Sector 102 Gurgaon          flat
# 4                3 BHK Flat in Sector 92 Gurgaon          flat
#
#                   society  price  price_per_square_feet    area  \
# 0             rof aalayas   0.45                 6000.0   750.0
# 1  huda sector-56 gurgaon   3.60                24845.0  1449.0
# 2   parsvnath green ville   2.50                12820.0  1950.0
# 3    emaar gurgaon greens   1.35                 8181.0  1650.0
# 4          raheja sampada   0.65                 4744.0  1370.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                   Built Up area: 750 (69.68 sq.m.)        1         1
# ...

# %% [markdown]
# We dont have sector in df2

# %%
wordcloud_df = df1.merge(df, left_index=True, right_index=True)[['features','sector']]

# %%
wordcloud_df.head()
# Out:
#                                             features      sector
# 0                                                NaN  sector 102
# 1  ['Feng Shui / Vaastu Compliant', 'Maintenance ...   sector 56
# 2  ['Feng Shui / Vaastu Compliant', 'Security / F...   sector 48
# 3  ['Security / Fire Alarm', 'Power Back-up', 'Fe...  sector 102
# 4  ['Feng Shui / Vaastu Compliant', 'Security / F...   sector 92

# %%
wordcloud_df[wordcloud_df['sector'] == 'sector 48']
# Out:
#                                                features     sector
# 2     ['Feng Shui / Vaastu Compliant', 'Security / F...  sector 48
# 113   ['Feng Shui / Vaastu Compliant', 'Intercom Fac...  sector 48
# 134   ['Security / Fire Alarm', 'Lift(s)', 'Maintena...  sector 48
# 168                                                 NaN  sector 48
# 211   ['Water purifier', 'Security / Fire Alarm', 'F...  sector 48
# 250   ['Intercom Facility', 'Lift(s)', 'Maintenance ...  sector 48
# 344   ['Feng Shui / Vaastu Compliant', 'Security / F...  sector 48
# 410   ['Security / Fire Alarm', 'Feng Shui / Vaastu ...  sector 48
# 452   ['Feng Shui / Vaastu Compliant', 'Security / F...  sector 48
# 619   ['Power Back-up', 'Feng Shui / Vaastu Complian...  sector 48
# 631   ['Feng Shui / Vaastu Compliant', 'Private Gard...  sector 48
# 850   ['Private Garden / Terrace', 'Water purifier',...  sector 48
# 894                                                 NaN  sector 48
# ...

# %%
import ast
main = []
for item in wordcloud_df['features'].dropna().apply(ast.literal_eval):
    main.extend(item)

# %%
main
# Out:
# ['Feng Shui / Vaastu Compliant',
#  'Maintenance Staff',
#  'Water Storage',
#  'Park',
#  'Piped-gas',
#  'Visitor Parking',
#  'Low Density Society',
#  'Waste Disposal',
#  'Rain Water Harvesting',
#  'Feng Shui / Vaastu Compliant',
#  'Security / Fire Alarm',
#  'Intercom Facility',
#  'Lift(s)',
#  'Maintenance Staff',
#  'Water Storage',
#  'Park',
#  'Visitor Parking',
#  'Security / Fire Alarm',
#  'Power Back-up',
#  'Feng Shui / Vaastu Compliant',
#  'Intercom Facility',
#  'Lift(s)',
#  'Maintenance Staff',
#  'Water Storage',
#  'Separate entry for servant room',
#  'No open drainage around',
#  'Visitor Parking',
#  'Swimming Pool',
#  'Park',
#  'Security Personnel',
#  'Natural Light',
#  'Airy Rooms',
#  'Internet/wi-fi connectivity',
#  'Shopping Centre',
#  'Fitness Centre / GYM',
#  'Waste Disposal',
#  'Rain Water Harvesting',
#  'Club house / Community Center',
#  'Water softening plant',
#  'Feng Shui / Vaastu Compliant',
#  'Security / Fire Alarm',
# ...

# %%
feature_text = ' '.join(main)

# %%
feature_text
# Out:
# 'Feng Shui / Vaastu Compliant Maintenance Staff Water Storage Park Piped-gas Visitor Parking Low Density Society Waste Disposal Rain Water Harvesting Feng Shui / Vaastu Compliant Security / Fire Alarm Intercom Facility Lift(s) Maintenance Staff Water Storage Park Visitor Parking Security / Fire Alarm Power Back-up Feng Shui / Vaastu Compliant Intercom Facility Lift(s) Maintenance Staff Water Storage Separate entry for servant room No open drainage around Visitor Parking Swimming Pool Park Security Personnel Natural Light Airy Rooms Internet/wi-fi connectivity Shopping Centre Fitness Centre / GYM Waste Disposal Rain Water Harvesting Club house / Community Center Water softening plant Feng Shui / Vaastu Compliant Security / Fire Alarm Intercom Facility Lift(s) Maintenance Staff Water Storage Park Visitor Parking Security / Fire Alarm Power Back-up Intercom Facility Lift(s) High Ceiling Height Maintenance Staff Piped-gas Visitor Parking Swimming Pool Park Internet/wi-fi connectivity Fit
# ...

# %%
pickle.dump(feature_text, open('feature_text.pkl','wb'))

# %%
plt.rcParams["font.family"] = "Arial"

wordcloud = WordCloud(width = 800, height = 800, 
                      background_color ='white', 
                      stopwords = set(['s']),  # Any stopwords you'd like to exclude
                      min_font_size = 10).generate(feature_text)

plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()
